# %% [markdown]
# # Preparing and working with the additional dataset customers.csv

# %% [markdown]
# # Table of content
# ## 1. Setting up and dataset exploration
# ## 2. Data wrangling
# ## 3. Data consistency checks
# ## 4. Combining datasets

# %% [markdown]
# # 1. Setting up and dataset exploration

# %%
import pandas as pd
import numpy as np
import os

# %%
# creating path for later import/export

path = r"C:\Users\Anwender\Documents\07-2023 Instacart Basket Analysis"

# %%
# importing df

df = pd.read_csv(os.path.join(path, "02 Data", "Original Data", "customers.csv"), index_col = False)

# %%
# exploring df

df.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df.tail()
# Out:
#         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
#         n_dependants fam_status  income
# 206204             1    married  148828
# 206205             3    married  168639
# 206206             2    married   53374
# 206207             1    married   99799
# 206208             1    married   57095

# %%
df.shape
# Out:
# (206209, 10)

# %%
df.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %% [markdown]
# #### user_id dtype needs to be changed to object.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %% [markdown]
# # 2. Data Wrangling

# %%
# renaming columns

df.rename(columns = {"Surnam": "Surname"}, inplace = True)

# %%
df.rename(columns = {"STATE": "State"}, inplace = True)

# %%
df.rename(columns = {"n_dependants": "number_of_dependents"}, inplace = True)

# %%
# checking output

df.head()
# Out:
#    user_id First Name   Surname  Gender       State  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependents fam_status  income
# 0                     3    married  165665
# 1                     0     single   59285
# 2                     2    married   99568
# 3                     0     single   42049
# 4                     1    married   40374

# %%
# changing dtypes to int32 for memory saving

df["user_id"] = df["user_id"].astype("int32")

# %%
df["Age"] = df["Age"].astype("int16")

# %%
df["number_of_dependents"] = df["number_of_dependents"].astype("int16")

# %%
df["income"] = df["income"].astype("int32")

# %%
#checking output

df.dtypes
# Out:
# user_id                  int32
# First Name              object
# Surname                 object
# Gender                  object
# State                   object
# Age                      int16
# date_joined             object
# number_of_dependents     int16
# fam_status              object
# income                   int32
# dtype: object

# %% [markdown]
# # 3. Data consistency checks

# %%
# checking for mixed type data

for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)
# Out:
# First Name

# %%
# changing dtype to object

df["First Name"] = df["First Name"].astype("str")

# %%
# checking again for mixed type data

for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)

# %%
# checking for missing values

df.isnull().sum()
# Out:
# user_id                 0
# First Name              0
# Surname                 0
# Gender                  0
# State                   0
# Age                     0
# date_joined             0
# number_of_dependents    0
# fam_status              0
# income                  0
# dtype: int64

# %% [markdown]
# #### No missing values found.

# %%
# checking for duplicates

df_dups = df[df.duplicated()]

# %%
df_dups.head()
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Surname, Gender, State, Age, date_joined, number_of_dependents, fam_status, income]
# Index: []

# %% [markdown]
# #### No duplicate values found.

# %% [markdown]
# # 4. Combining datasets

# %%
#importing derived df from previous lessons

df_2 = pd.read_pickle(os.path.join(path,"02 Data", "Prepared Data", "df_derived_3.pkl"))

# %%
df_2.shape
# Out:
# (32404859, 22)

# %%
df_2.dtypes
# Out:
# order_id                        int32
# user_id                         int32
# amount_of_orders                int16
# orders_day_of_week              int16
# order_hour_of_day               int16
# days_since_prior_order        float16
# product_id                      int32
# add_to_cart_order               int16
# reordered                       int32
# product_name                   object
# aisle_id                        int32
# department_id                   int32
# prices                        float32
# price_range_loc                object
# busiest_days                   object
# busiest_period_of_day          object
# max_order                       int32
# loyalty_flag                   object
# average_spending                int32
# spending_flag                  object
# median_days_previous_order    float32
# order_frequency                object
# dtype: object

# %%
# test merging both dfs

pd.merge(df, df_2, on = ["user_id"], indicator = True)
# Out:
#           user_id First Name   Surname  Gender     State  Age date_joined  \
# 0           26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 1           26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 2           26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 3           26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 4           26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# ...           ...        ...       ...     ...       ...  ...         ...
# 32404854    80148    Cynthia     Noble  Female  New York   55    4/1/2020
# 32404855    80148    Cynthia     Noble  Female  New York   55    4/1/2020
# 32404856    80148    Cynthia     Noble  Female  New York   55    4/1/2020
# 32404857    80148    Cynthia     Noble  Female  New York   55    4/1/2020
# 32404858    80148    Cynthia     Noble  Female  New York   55    4/1/2020
#
#           number_of_dependents fam_status  income  ...    price_range_loc  \
# ...

# %%
# merging both dfs

df_merged = df.merge(df_2, on = ["user_id"], indicator = True)

# %%
df_merged.head()
# Out:
#    user_id First Name   Surname  Gender     State  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 1    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 2    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 3    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 4    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
#
#    number_of_dependents fam_status  income  ...    price_range_loc  \
# 0                     3    married  165665  ...  Mid-range product
# 1                     3    married  165665  ...  Mid-range product
# 2                     3    married  165665  ...  Mid-range product
# 3                     3    married  165665  ...  Mid-range product
# 4                     3    married  165665  ...  Mid-range product
#
#      busiest_days  busiest_period_of_day  max_order  loyalty_flag  \
# 0    Busiest days         Average orders          8  New customer
# ...

# %%
# Exporting df_merged

df_merged.to_pickle(os.path.join(path, "02 Data", "Prepared Data", "df_merged_final.pkl"))
